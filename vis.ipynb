# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sqlite3

conn = sqlite3.connect('bookstore.db')
print("Successfull connection")
# Out:
# Successfull connection

# %%
xpoints = np.array([0,10])
ypoints = np.array([0,250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import pandas as pd
import numpy as np

data1 = pd.DataFrame({
    'name':    [23, 45, 31, 52, 28, 37, 41, 26, 33, 48],
    'quantity': [30000, 85000, 52000, 97000, 41000, 63000, 78000, 35000, 58000, 91000],
    'perf_score':  [72, 88, 65, 91, 70, 83, 87, 68, 75, 90]
})

print(data1)

# %%
genre = df["genre"].to_numpy()
quantity = df["quantity"].to_numpy()
plt.figure(figsize=(10,5))
plt.bar(genre, quantity)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

genre = df["genre"].to_numpy()
quantity = df["quantity"].to_numpy()

plt.figure(figsize=(10, 10))
plt.pie(quantity, labels=genre, autopct="%1.1f%%")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['genre', 'quantity'], dtype='object')

# %%
df = pd.read_sql("""
SELECT
    o.quantity,
    b.price,
    b.title
FROM books b
JOIN orders o
    ON o.book_id = b.book_id
""", conn)

# %%
price = df["price"].to_numpy()
title = df["title"].to_numpy()

plt.figure(figsize=(10,5))
plt.hist(price, bins=10)
plt.show()

# %%
df = pd.read_sql("""
SELECT
    c.name,
    c.city,
    o.quantity
FROM customers c
JOIN orders o
    ON c.customer_id = o.customer_id
""", conn)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.countplot(x="city", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
city_counts = df["city"].value_counts()

plt.figure(figsize=(10,5))
plt.bar(city_counts.index, city_counts.values)
plt.xticks(rotation=45)
plt.show()
