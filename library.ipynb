# %%
class Book:
    def __init__(self,title,author,copies_available):
        self.title = title
        self.author = author
        self.copiies = copies_available
    
    def borrow_quantity(self,quantity):
        
       
    def return_copy(self,quantity):
         self.coppies_available += quantity

    def display_info(self):
        print(f"Tilte:" {self.title})
        print(f"Author:" {self.author})
        print(f"Copies_Available:" {self.copies_available})
# Out:
#   Cell In[1], line 9
#     def return_copy(self,quantity):
#     ^
# IndentationError: expected an indented block after function definition on line 7
